# %%
import numpy
import pandas
import statsmodels.api as sm
import seaborn
import statsmodels.formula.api as smf 
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200

# %%
pandas.set_option('display.float_format', lambda x:'%.2f'%x)

# %%
data = pandas.read_csv('/content/drive/My Drive/data/nesarc.csv', low_memory=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43093 entries, 0 to 43092
# Columns: 3010 entries, Unnamed: 0 to NDSymptoms
# dtypes: float64(27), int64(655), object(2328)
# memory usage: 989.6+ MB

# %%
data['IDNUM'] =pandas.to_numeric(data['IDNUM'], errors='coerce')
data['TAB12MDX'] = pandas.to_numeric(data['TAB12MDX'], errors='coerce')
data['MAJORDEPLIFE'] = pandas.to_numeric(data['MAJORDEPLIFE'], errors='coerce')
data['NDSymptoms'] = pandas.to_numeric(data['NDSymptoms'], errors='coerce')
data['SOCPDLIFE'] = pandas.to_numeric(data['SOCPDLIFE'], errors='coerce')
data['S3AQ3C1'] = pandas.to_numeric(data['S3AQ3C1'], errors='coerce')
data['AGE'] =pandas.to_numeric(data['AGE'], errors='coerce')
data['SEX'] = pandas.to_numeric(data['SEX'], errors='coerce')
data['S3AQ3B1'] = pandas.to_numeric(data['S3AQ3B1'], errors='coerce')

sub1=data[(data['AGE']<=25) & (data['CHECK321']==1) & (data['S3AQ3B1']==1)]

# %%
sub1['numbercigsmoked_c'] = (sub1['S3AQ3C1'] - sub1['S3AQ3C1'].mean())
print (sub1['numbercigsmoked_c'].mean()) 
print()
# Out:
# -1.4580929056743724e-14
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
reg2 = smf.ols('NDSymptoms ~ MAJORDEPLIFE + numbercigsmoked_c', data=sub1).fit()
print (reg2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             NDSymptoms   R-squared:                       0.118
# Model:                            OLS   Adj. R-squared:                  0.117
# Method:                 Least Squares   F-statistic:                     88.38
# Date:                Wed, 28 Oct 2020   Prob (F-statistic):           9.66e-37
# Time:                        09:06:33   Log-Likelihood:                -2618.6
# No. Observations:                1320   AIC:                             5243.
# Df Residuals:                    1317   BIC:                             5259.
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             2.1871      0.057     38.569      0.000       2.076       2.298
# MAJORDEPLIFE          1.3381      0.109     12.229      0.000       1.123       1.553
# numbercigsmoked_c     0.0226      0.005      4.701      0.000       0.013       0.032
# ==============================================================================
# Omnibus:                       67.603   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.557
# Skew:                           0.365   Prob(JB):                     2.86e-11
# Kurtosis:                       2.408   Cond. No.                         23.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
reg3 = smf.ols('NDSymptoms ~ DYSLIFE', data=sub1).fit()
print (reg3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             NDSymptoms   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     30.62
# Date:                Wed, 28 Oct 2020   Prob (F-statistic):           3.78e-08
# Time:                        09:23:52   Log-Likelihood:                -2686.5
# No. Observations:                1320   AIC:                             5377.
# Df Residuals:                    1318   BIC:                             5387.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.4724      0.053     46.859      0.000       2.369       2.576
# DYSLIFE        1.1438      0.207      5.533      0.000       0.738       1.549
# ==============================================================================
# Omnibus:                      124.488   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.875
# Skew:                           0.376   Prob(JB):                     1.35e-14
# Kurtosis:                       2.228   Cond. No.                         4.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
reg4 = smf.ols('NDSymptoms ~ DYSLIFE + MAJORDEPLIFE', data=sub1).fit()
print (reg4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             NDSymptoms   R-squared:                       0.106
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     77.67
# Date:                Wed, 28 Oct 2020   Prob (F-statistic):           1.30e-32
# Time:                        09:24:47   Log-Likelihood:                -2628.1
# No. Observations:                1320   AIC:                             5262.
# Df Residuals:                    1317   BIC:                             5278.
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        2.1761      0.057     38.054      0.000       2.064       2.288
# DYSLIFE          0.3585      0.210      1.705      0.088      -0.054       0.771
# MAJORDEPLIFE     1.2920      0.117     11.041      0.000       1.062       1.522
# ==============================================================================
# Omnibus:                       71.014   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.262
# Skew:                           0.379   Prob(JB):                     7.39e-12
# Kurtosis:                       2.401   Cond. No.                         4.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sub1['age_c']=(sub1['AGE'] - sub1['AGE'].mean())
print (sub1['age_c'].mean())
# Out:
# -3.445055688533819e-16
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
reg5 = smf.ols('NDSymptoms ~ DYSLIFE + MAJORDEPLIFE + numbercigsmoked_c + age_c + SEX', data=sub1).fit()
print (reg5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             NDSymptoms   R-squared:                       0.123
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     36.77
# Date:                Wed, 28 Oct 2020   Prob (F-statistic):           2.37e-35
# Time:                        09:28:09   Log-Likelihood:                -2615.2
# No. Observations:                1320   AIC:                             5242.
# Df Residuals:                    1314   BIC:                             5274.
# Df Model:                           5
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             2.3307      0.156     14.944      0.000       2.025       2.637
# DYSLIFE               0.3142      0.209      1.502      0.133      -0.096       0.725
# MAJORDEPLIFE          1.2937      0.117     11.076      0.000       1.065       1.523
# numbercigsmoked_c     0.0218      0.005      4.516      0.000       0.012       0.031
# age_c                -0.0392      0.022     -1.763      0.078      -0.083       0.004
# SEX                  -0.1007      0.099     -1.016      0.310      -0.295       0.094
# ==============================================================================
# Omnibus:                       68.719   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.568
# Skew:                           0.353   Prob(JB):                     4.68e-11
# Kurtosis:                       2.394   Cond. No.                         44.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
